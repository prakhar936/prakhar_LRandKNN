# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split as tt
from sklearn.neighbors import KNeighborsClassifier

# %%
dtrain = pd.read_csv(r"C:\Users\91936\Desktop\Logistic and KNN\mobile_data.csv")
dtrain.head()
dtrain.shape
# Out:
# (2000, 21)

# %%
sns.heatmap(dtrain.corr(),annot = True)
plt.show()

# %%
dtrain.corr()
# Out:
#                battery_power      blue  clock_speed  dual_sim        fc  \
# battery_power       1.000000  0.011252     0.011482 -0.041847  0.033334
# blue                0.011252  1.000000     0.021419  0.035198  0.003593
# clock_speed         0.011482  0.021419     1.000000 -0.001315 -0.000434
# dual_sim           -0.041847  0.035198    -0.001315  1.000000 -0.029123
# fc                  0.033334  0.003593    -0.000434 -0.029123  1.000000
# four_g              0.015665  0.013443    -0.043073  0.003187 -0.016560
# int_memory         -0.004004  0.041177     0.006545 -0.015679 -0.029133
# m_dep               0.034085  0.004049    -0.014364 -0.022142 -0.001791
# mobile_wt           0.001844 -0.008605     0.012350 -0.008979  0.023618
# n_cores            -0.029727  0.036161    -0.005724 -0.024658 -0.013356
# pc                  0.031441 -0.009952    -0.005245 -0.017143  0.644595
# px_height           0.014901 -0.006872    -0.014523 -0.020875 -0.009990
# ...

# %%
dtrain.drop(['blue','pc' ,'clock_speed','dual_sim','fc','four_g','int_memory','m_dep','mobile_wt','n_cores','sc_h','sc_w','talk_time','three_g','touch_screen','wifi'], axis = 1, inplace = True)

# %%
dtrain.head()
# Out:
#    battery_power  px_height  px_width   ram  price_range
# 0            842         20       756  2549            1
# 1           1021        905      1988  2631            2
# 2            563       1263      1716  2603            2
# 3            615       1216      1786  2769            2
# 4           1821       1208      1212  1411            1

# %%
sns.heatmap(dtrain.corr(),annot = True)
# Out:
# <Axes: >

# %%
sns.scatterplot(x=dtrain['ram'], y=dtrain['price_range'])
plt.show()

# %%
sns.scatterplot(x=dtrain['px_width'], y=dtrain['price_range'])
plt.show()

# %%
sns.scatterplot(x=dtrain['px_height'], y=dtrain['price_range'])
plt.show()

# %%
sns.scatterplot(x=dtrain['battery_power'], y=dtrain['price_range'])
plt.show()

# %%
sns.scatterplot(x=dtrain['px_width'], y=dtrain['px_height'])
plt.show()

# %%
x = dtrain.drop('price_range',axis = 1)
y = dtrain['price_range']
x_train,x_test,y_train,y_test = tt(x,y,random_state = 42)

neighbors = np.arange(1,50)

train_accuracy = np.empty(len(neighbors))
test_accuracy = np.empty(len(neighbors))

for i,k in enumerate(neighbors):
    k = KNeighborsClassifier(n_neighbors = k)
    k.fit(x_train,y_train)
    
    train_accuracy[i] = k.score(x_train,y_train)
    test_accuracy[i] = k.score(x_test,y_test)
    
plt.plot(neighbors,test_accuracy,label = "test")
plt.plot(neighbors,train_accuracy,label = "train")
plt.legend()

# %%
algo = KNeighborsClassifier(n_neighbors = 9)
algo.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=9)

# %%
y_pred = algo.predict(x_test)

# %%
algo.score(x_test,y_test)
# Out:
# 0.948
